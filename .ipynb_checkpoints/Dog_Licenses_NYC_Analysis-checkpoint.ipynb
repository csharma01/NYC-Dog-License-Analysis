# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dog_data = pd.read_csv('NYC_Dog_Licensing_Dataset_20241105.csv')
dog_data.head()
# Out:
# C:\Users\cshar\AppData\Local\Temp\ipykernel_22664\421662572.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   dog_data = pd.read_csv('NYC_Dog_Licensing_Dataset_20241105.csv')
#   AnimalName AnimalGender AnimalBirthYear  \
# 0      PAIGE            F            2014
# 1       YOGI            M            2010
# 2        ALI            M            2014
# 3      QUEEN            F            2013
# 4       LOLA            F            2009
#
#                               BreedName  ZipCode LicenseIssuedDate  \
# 0  American Pit Bull Mix / Pit Bull Mix  10035.0        09-12-2014
# 1                                 Boxer  10465.0        09-12-2014
# 2                               Basenji  10013.0        09-12-2014
# 3                      Akita Crossbreed  10013.0        09-12-2014
# 4                               Maltese  10028.0        09-12-2014
#
#   LicenseExpiredDate  Extract Year
# 0         09-12-2017          2016
# ...

# %%
#Data Cleaning

#Converting the dates into Pandas Datetime format
dog_data['LicenseIssuedDate'] = pd.to_datetime(dog_data['LicenseIssuedDate'], errors='coerce')
dog_data['LicenseExpiredDate'] = pd.to_datetime(dog_data['LicenseExpiredDate'], errors='coerce')

#converting AnimalBirthYear to integer and setting any problematic value to NaN using 'coerce'
dog_data['AnimalBirthYear'] = pd.to_numeric(dog_data['AnimalBirthYear'], errors='coerce')

#exploring the total missing values in each column
print(dog_data.isnull().sum())
# Out:
# AnimalName              1387
# AnimalGender              21
# AnimalBirthYear           30
# BreedName                  0
# ZipCode                    9
# LicenseIssuedDate     370485
# LicenseExpiredDate    389919
# Extract Year               0
# dtype: int64

# %%
# I have chosen to drop the missing values
dog_data.dropna(subset=['LicenseIssuedDate', 'LicenseExpiredDate'], inplace=True)
dog_data.dropna(subset=['AnimalGender'], inplace=True)
dog_data.dropna(subset=['ZipCode'], inplace=True)

dog_data.isnull().sum()
# Out:
# AnimalName            498
# AnimalGender            0
# AnimalBirthYear         9
# BreedName               0
# ZipCode                 0
# LicenseIssuedDate       0
# LicenseExpiredDate      0
# Extract Year            0
# dtype: int64

# %%
#Converting the missing values with an 'unknown' value
dog_data['AnimalName'].fillna('Unknown', inplace=True)

# dropping the few birth year missing values
dog_data.dropna(subset=['AnimalBirthYear'], inplace=True)

dog_data.isnull().sum()
# Out:
# C:\Users\cshar\AppData\Local\Temp\ipykernel_22664\989620026.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dog_data['AnimalName'].fillna('Unknown', inplace=True)
# AnimalName            0
# AnimalGender          0
# AnimalBirthYear       0
# BreedName             0
# ZipCode               0
# LicenseIssuedDate     0
# LicenseExpiredDate    0
# Extract Year          0
# dtype: int64

# %%
# Adding a column for dog's age when the license was first issued for it
# Extracting the year from 'LicenseIssuedDate'
dog_data['LicenseIssuedYear'] = dog_data['LicenseIssuedDate'].dt.year

dog_data['AgeAtLicenseIssuance'] = dog_data['LicenseIssuedYear'] - dog_data['AnimalBirthYear']

#calculating the annual licenses issued using Extract year
annual_licenses = dog_data['Extract Year'].value_counts().sort_index()

#Adding a new column for License Duration in days and encoding the Gender column into 1 and 0
dog_data['LicenseDuration'] = (dog_data['LicenseExpiredDate'] - dog_data['LicenseIssuedDate']).dt.days
dog_data['GenderEncoded'] = dog_data['AnimalGender'].replace({'M': 1, 'F': 0})

#Filtering out the outliers from the age by setting a max realistic for dogs as 20
dog_data = dog_data[(dog_data['AgeAtLicenseIssuance'] >= 0) & (dog_data['AgeAtLicenseIssuance'] <= 20)]

#basic statistics on the dogs dataset with newly created column
dog_data.describe()
# Out:
# C:\Users\cshar\AppData\Local\Temp\ipykernel_22664\767477394.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dog_data['GenderEncoded'] = dog_data['AnimalGender'].replace({'M': 1, 'F': 0})
#        AnimalBirthYear        ZipCode              LicenseIssuedDate  \
# count    152359.000000  152359.000000                         152359
# mean       2015.411935   10712.569582  2019-07-31 11:00:21.430962432
# min        1996.000000     100.000000            2014-09-12 00:00:00
# 25%        2012.000000   10031.000000            2017-09-09 00:00:00
# 50%        2016.000000   10472.000000            2019-11-02 00:00:00
# 75%        2019.000000   11226.000000            2021-04-03 00:00:00
# max        2023.000000   99508.000000            2023-11-01 00:00:00
# ...

# %%
#Plot 1: Histogram of dog ages at license issuance
def plot_dog_age_histogram(dog_data):
    '''
    plots a histogram displaying the distribution of column AgeAtLicenseIssuance in dog_data dataframe 
    '''
    
    plt.figure(figsize=(10, 6))
    sns.histplot(dog_data['AgeAtLicenseIssuance'], bins=20)
    plt.title('Distribution of Dog Ages at License Issuance',size="20")
    plt.xlabel('Age at License Issuance', size='14')
    plt.ylabel('Number of Dogs', size = '14')
    plt.xticks(size='12')
    plt.yticks(size='12')
    plt.show()

plot_dog_age_histogram(dog_data)

# %%
#Plot 2: Line plot for licenses issued each year
def plot_annual_license(dog_data):
    '''
    plots a line chart showing the annual trends of dog license issuing using Age and 
    '''
    
    plt.figure(figsize=(10, 6))
    sns.lineplot(x=annual_licenses.index, y=annual_licenses.values)
    plt.title('Annual Dog Licensing Trends', size = '20')
    plt.xlabel('Year', size = '14')
    plt.ylabel('Number of Licenses Issued', size = '14')
    plt.xticks(size = '12')
    plt.yticks(size = '12')
    plt.grid(True)
    plt.show()

plot_annual_license(dog_data)

# %%
def plot_age_breed(dog_data):
    '''
    plots a boxplot for age distribution by popular breeds in NYC
    '''
    
    # Selecting the top 10 most common breeds
    top_breeds = dog_data['BreedName'].value_counts().nlargest(10).index
    top_common_breeds = dog_data[dog_data['BreedName'].isin(top_breeds)]
    
    #Plot 3: creating the box plot to display age distribution for top breeds
    plt.figure(figsize=(12, 8))
    sns.boxplot(x='BreedName', y='AgeAtLicenseIssuance', data=top_common_breeds, color='skyblue')
    plt.xticks(rotation=90, size = '12')
    plt.yticks(size = '12')
    plt.title('Age Distribution by Breed for Most Common Breeds', size = '20')
    plt.xlabel('Breeds', size = '14')
    plt.ylabel('Age at License Issuance', size = '14')
    plt.show()

plot_age_breed(dog_data)

# %%
#Plot 4: Plotting a heatmap to visualise any correlation between the columns
def correlation_matrix(dog_data):
    '''
    plots a correlation matrix of the numerical columns from dog_data
    '''
    
    numerical_columns = ['Extract Year', 'LicenseDuration', 'AgeAtLicenseIssuance', 'LicenseIssuedYear', 'GenderEncoded']
    
    # calculating the correlation between the numerical columns
    correlation_matrix = dog_data[numerical_columns].corr()
    

    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm',annot_kws={'size': 14})
    plt.title('Correlation Matrix', size = '20')
    plt.xticks(size = '12')
    plt.yticks(size = '12')
    plt.show()
    
    return correlation_matrix

correlation_matrix(dog_data)
# Out:
#                       Extract Year  LicenseDuration  AgeAtLicenseIssuance  \
# Extract Year              1.000000         0.105592             -0.024088
# LicenseDuration           0.105592         1.000000              0.012593
# AgeAtLicenseIssuance     -0.024088         0.012593              1.000000
# LicenseIssuedYear         0.918226         0.041247             -0.017877
# GenderEncoded            -0.008233        -0.015738             -0.026090
#
#                       LicenseIssuedYear  GenderEncoded
# Extract Year                   0.918226      -0.008233
# LicenseDuration                0.041247      -0.015738
# AgeAtLicenseIssuance          -0.017877      -0.026090
# LicenseIssuedYear              1.000000      -0.007824
# GenderEncoded                 -0.007824       1.000000
